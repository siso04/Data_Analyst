# %%
import pandas as pd

# %%
ufo = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv')
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %% [markdown]
# ### Seleccion con corchetes [ ]

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
ufo['Colors Reported'].value_counts()
# Out:
# RED                       780
# GREEN                     531
# ORANGE                    528
# BLUE                      450
# YELLOW                    169
# RED GREEN                  89
# RED BLUE                   78
# RED ORANGE                 44
# GREEN BLUE                 34
# RED GREEN BLUE             33
# ORANGE YELLOW              26
# RED YELLOW                 25
# ORANGE GREEN               23
# YELLOW GREEN               17
# ORANGE BLUE                10
# RED YELLOW GREEN            9
# YELLOW BLUE                 6
# YELLOW GREEN BLUE           5
# ORANGE GREEN BLUE           5
# RED YELLOW GREEN BLUE       4
# RED ORANGE YELLOW           4
# RED YELLOW BLUE             3
# RED ORANGE GREEN            3
# RED ORANGE BLUE             3
# RED ORANGE YELLOW BLUE      1
# ORANGE YELLOW GREEN         1
# ORANGE YELLOW BLUE          1
# Name: Colors Reported, dtype: int64

# %% [markdown]
# ### Seleccion con puntos (no lleva corchetes) - No funciona con columnas que tengan espacio

# %%
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %% [markdown]
# ### Como unir dos columnas con el simbolo de suma +

# %%
# Para unir dos columnas solo tenemos que concatenarlas con el simbolo de suma +
ufo.City + ", " + ufo.State
# Out:
# 0                      Ithaca, NY
# 1                 Willingboro, NJ
# 2                     Holyoke, CO
# 3                     Abilene, KS
# 4        New York Worlds Fair, NY
#                    ...
# 18236              Grant Park, IL
# 18237             Spirit Lake, IA
# 18238             Eagle River, WI
# 18239             Eagle River, WI
# 18240                    Ybor, FL
# Length: 18241, dtype: object

# %%
# Ahora podemos agregar esa columna al data frame
ufo['Location'] = ufo.City + ", " + ufo.State
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time                  Location
# 0        6/1/1930 22:00                Ithaca, NY
# 1       6/30/1930 20:00           Willingboro, NJ
# ...

# %%
ufo.describe(include=['object'])
# Out:
#            City Colors Reported Shape Reported  State              Time  \
# count     18216            2882          15597  18241             18241
# unique     6476              27             27     52             16145
# top     Seattle             RED          LIGHT     CA  11/16/1999 19:00
# freq        187             780           2803   2529                27
#
#            Location
# count         18216
# unique         8029
# top     Seattle, WA
# freq            187
