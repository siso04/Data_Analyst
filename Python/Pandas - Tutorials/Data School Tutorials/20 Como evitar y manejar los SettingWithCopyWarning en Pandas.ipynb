# %%
import pandas as pd

# %%
movies = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv')
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies[movies['content_rating'].isnull()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
movies['content_rating'].unique()
# Out:
# array(['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED', 'APPROVED', 'PASSED',
#        'G', 'X', nan, 'TV-MA', 'GP', 'NC-17'], dtype=object)

# %%
# Vamos a pasar las peliculas que estan "NOT RATED" a missing values
movies[movies['content_rating'] == 'NOT RATED']
# Out:
#      star_rating                            title content_rating      genre  \
# 5            8.9                     12 Angry Men      NOT RATED      Drama
# 6            8.9   The Good, the Bad and the Ugly      NOT RATED    Western
# 41           8.5                     Sunset Blvd.      NOT RATED      Drama
# 63           8.4                                M      NOT RATED      Crime
# 66           8.4              Munna Bhai M.B.B.S.      NOT RATED     Comedy
# ..           ...                              ...            ...        ...
# 665          7.7                           Lolita      NOT RATED      Drama
# 673          7.7                          Blow-Up      NOT RATED      Drama
# 763          7.6                           Hunger      NOT RATED  Biography
# 827          7.5  The Wind That Shakes the Barley      NOT RATED      Drama
# 899          7.5                      In the Loop      NOT RATED     Comedy
#
# ...

# %%
# Tenemos que importar numpy para hacer esta operacion
import numpy as np

# %% [markdown]
# ## Aparece una advertencia: Try using .loc[row_indexer,col_indexer] = value instead

# %%
movies[movies['content_rating'] == 'NOT RATED']['content_rating'] = np.nan
# Out:
# C:\Users\equipo\AppData\Local\Temp\ipykernel_3732\3492396088.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies[movies['content_rating'] == 'NOT RATED']['content_rating'] = np.nan

# %% [markdown]
# ### La solucion es aplicar .loc

# %%
# La advertencia nos dice: debe seleccionar el indice de la fila y el indice de la columna, y luego asignar el valor
# es decir, debemos seleccionar una columna con una condicion, que es el indice, y luego repetir a columna, que es donde
# se aplicara esa condicion.
# A toda esa operacion le aplicamos el metodo con un simbolo de igual
movies.loc[movies['content_rating'] == 'NOT RATED', 'content_rating'] = np.nan

# %%
movies[movies['content_rating'].isnull()]
# Out:
#      star_rating                            title content_rating      genre  \
# 5            8.9                     12 Angry Men            NaN      Drama
# 6            8.9   The Good, the Bad and the Ugly            NaN    Western
# 41           8.5                     Sunset Blvd.            NaN      Drama
# 63           8.4                                M            NaN      Crime
# 66           8.4              Munna Bhai M.B.B.S.            NaN     Comedy
# ..           ...                              ...            ...        ...
# 673          7.7                          Blow-Up            NaN      Drama
# 763          7.6                           Hunger            NaN  Biography
# 827          7.5  The Wind That Shakes the Barley            NaN      Drama
# 899          7.5                      In the Loop            NaN     Comedy
# 936          7.4                        True Grit            NaN  Adventure
#
# ...

# %%
top_movies = movies.loc[(movies['star_rating'] >= 9)]

# %%
top_movies
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %% [markdown]
# ## Corregir el error agregando a la tabla .copy()

# %%
top_movies.loc[0, 'duration'] == 150
# Out:
# False

# %%
top_movies
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...

# %%
# Cuando se crea un data frame nuevo, es importante ser explicito y colocar la funcion "copy()" al final
top_movies = movies.loc[(movies['star_rating'] >= 9)].copy()

# %%
top_movies
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
