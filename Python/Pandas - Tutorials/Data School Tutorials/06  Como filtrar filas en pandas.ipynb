# %%
import pandas as pd

# %%
movies = pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv')
movies
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %% [markdown]
# ### Filtrar con un condicional y una variable

# %%
# Para filtrar con un condicional, creamos una variable de filtro
filtro = (movies['duration'] >= 150)

# %%
movies[filtro]
# Out:
#      star_rating                                  title content_rating  \
# 1            9.2                          The Godfather              R
# 2            9.1                 The Godfather: Part II              R
# 3            9.0                        The Dark Knight          PG-13
# 4            8.9                           Pulp Fiction              R
# 6            8.9         The Good, the Bad and the Ugly      NOT RATED
# ..           ...                                    ...            ...
# 909          7.5  Harry Potter and the Sorcerer's Stone             PG
# 941          7.4                       A Bridge Too Far             PG
# 955          7.4                       Zero Dark Thirty              R
# 964          7.4                                Lincoln          PG-13
# 968          7.4                    The English Patient              R
#
#          genre  duration                                        actors_list
# ...

# %% [markdown]
# ### Aplicar un filtro directo al data frame - df[(df[‘columna’] condicion)]

# %%
# Para hacerlo, creamos el filtro y lo aplicamos directo al data frame df[(filtro)]
movies[(movies['duration'] >= 150)]
# Out:
#      star_rating                                  title content_rating  \
# 1            9.2                          The Godfather              R
# 2            9.1                 The Godfather: Part II              R
# 3            9.0                        The Dark Knight          PG-13
# 4            8.9                           Pulp Fiction              R
# 6            8.9         The Good, the Bad and the Ugly      NOT RATED
# ..           ...                                    ...            ...
# 909          7.5  Harry Potter and the Sorcerer's Stone             PG
# 941          7.4                       A Bridge Too Far             PG
# 955          7.4                       Zero Dark Thirty              R
# 964          7.4                                Lincoln          PG-13
# 968          7.4                    The English Patient              R
#
#          genre  duration                                        actors_list
# ...

# %% [markdown]
# ### Filtrar con .loc y dos o mas variables

# %%
# Filtrar con .loc y dos o mas variables
movies.loc[filtro, ['title','star_rating','duration']].sort_values(by='star_rating', 
                                                                   ascending = False).head(20)
# Out:
#                                                 title  star_rating  duration
# 1                                       The Godfather          9.2       175
# 2                              The Godfather: Part II          9.1       200
# 3                                     The Dark Knight          9.0       152
# 4                                        Pulp Fiction          8.9       154
# 6                      The Good, the Bad and the Ugly          8.9       161
# 7       The Lord of the Rings: The Return of the King          8.9       201
# 8                                    Schindler's List          8.9       195
# 10  The Lord of the Rings: The Fellowship of the Ring          8.8       178
# 14              The Lord of the Rings: The Two Towers          8.8       179
# 17                                      Seven Samurai          8.7       207
# 15                                       Interstellar          8.7       169
# ...

# %% [markdown]
# ### Aplicar filtros dobles - Dos condiciones & u |

# %%
filtro = (movies['duration'] >= 180) & (movies['genre'] == 'Drama')

# %%
movies[(movies['duration'] >= 180) & (movies['genre'] == 'Drama')]
# Out:
#      star_rating                  title content_rating  genre  duration  \
# 17           8.7          Seven Samurai        UNRATED  Drama       207
# 89           8.4                 Swades      NOT RATED  Drama       189
# 132          8.3  Judgment at Nuremberg      NOT RATED  Drama       186
# 157          8.2     Gone with the Wind              G  Drama       238
# 166          8.2        The Deer Hunter              R  Drama       182
# 184          8.2    Fanny and Alexander              R  Drama       188
# 316          8.0                    JFK              R  Drama       189
# 318          8.0               Magnolia              R  Drama       188
# 335          8.0         Doctor Zhivago          PG-13  Drama       197
# 361          8.0    Fiddler on the Roof              G  Drama       181
# 476          7.8                 Hamlet          PG-13  Drama       242
# 620          7.7                Titanic          PG-13  Drama       194
#
# ...

# %%
movies[(movies['duration'] >= 180) | (movies['genre'] == 'Drama')]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 5            8.9                                   12 Angry Men
# 7            8.9  The Lord of the Rings: The Return of the King
# 8            8.9                               Schindler's List
# 9            8.9                                     Fight Club
# ..           ...                                            ...
# 958          7.4                             My Sister's Keeper
# 968          7.4                            The English Patient
# 970          7.4                                    Wonder Boys
# 972          7.4                                 Blue Valentine
# 973          7.4                          The Cider House Rules
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 5        NOT RATED      Drama        96
# 7            PG-13  Adventure       201
# ...

# %% [markdown]
# ### Filtrar multiples condiciones de OR con isin()

# %%
# Creamos las condiciones del filtro, pero dentro de la funcion isin()
movies[(movies['genre'].isin(['Crime', 'Drama', 'Adventure']))]
# Out:
#      star_rating                        title content_rating      genre  \
# 0            9.3     The Shawshank Redemption              R      Crime
# 1            9.2                The Godfather              R      Crime
# 2            9.1       The Godfather: Part II              R      Crime
# 4            8.9                 Pulp Fiction              R      Crime
# 5            8.9                 12 Angry Men      NOT RATED      Drama
# ..           ...                          ...            ...        ...
# 970          7.4                  Wonder Boys              R      Drama
# 972          7.4               Blue Valentine          NC-17      Drama
# 973          7.4        The Cider House Rules          PG-13      Drama
# 975          7.4  Back to the Future Part III             PG  Adventure
# 978          7.4                  Wall Street              R      Crime
#
#      duration                                        actors_list
# ...

# %%
import numpy as np

# %%
movies.select_dtypes(include=object).dtypes
# Out:
# title             object
# content_rating    object
# genre             object
# actors_list       object
# dtype: object

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
#query() allows Boolean expressions for filtering rows.
#df.query('Length > 7')
#df.query('Length > 7 and Width < 8')
#df.query('Name.str.startswith("abc")', 
#engine="python")

# %%
movies.head(5)
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.query('duration > 200').sort_values(by='star_rating', ascending = False)
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...
